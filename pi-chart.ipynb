# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

import pandas as pd
df = pd.read_excel('MZ세대 행정동별 데이터셋 (최종).xlsx')
df.head()


from matplotlib import font_manager, rc
import platform
import matplotlib

# %matplotlib inline 


if platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
    rc('font', family = font_name)
else:
    rc('font',family='AppleGothic')
    
matplotlib.rcParams['axes.unicode_minus']=False
# %matplotlib inline

df
# Out:
#      행정동  MZ세대 평균 소비 금액   평균연령  세대당인구    M세대인구비율    Z세대인구비율    아파트수 비율  \
# 0    진잠동    269099.0558  41.85  2.195  21.214741  13.481807  11.854096
# 1   온천1동    246080.5469  42.50  1.500  28.897567  22.082457   0.852929
# 2   온천2동    320283.5195  39.60  1.960  23.100837  21.202928  11.172498
# 3   노은1동    137041.6893  39.00  2.430  22.800317  12.417905  20.526159
# 4   노은2동    141482.2677  40.20  2.520  19.835573  12.741007   8.971271
# 5   노은3동    227484.4917  38.40  2.610  24.356715   9.674358   0.000000
# 6    신성동    204991.6024  37.10  2.160  29.124236  14.337317   4.627170
# 7    전민동    189966.1348  38.80  2.320  24.707597  14.457606   9.492712
# 8    구즉동    194207.3404  40.30  2.260  23.799810  13.885274  12.810071
# 9    관평동    180504.9839  37.00  2.630  21.739436  13.270759   9.547339
# 10  원신흥동    334783.3676  38.00  2.460  25.287070  10.121729  10.145755
#
#      주상복합수 비율  도시 생활형주택수 비율   연립주택수 비율  ...  가구소득 600만원 이상  1인당 평균 소비 금액  \
# ...

# %%
import matplotlib.pyplot as plt

ratio = [8.333333333333333, 8.333333333333333, 8.333333333333333, 8.333333333333333, 8.333333333333333, 8.333333333333333, 8.333333333333333, 8.333333333333333, 8.333333333333333, 8.333333333333333, 8.333333333333333, 8.333333333333333]
labels = ['M세대인구비율', 'Z세대인구비율', '아파트수 비율', '주상복합수 비율', '도시 생활형주택수 비율', '연립주택수 비율',
         '가구소득 600만원 이상', '1인당 평균 소비 금액', 'M세대사업체수비율', 'M세대종사자수비율', '사업체유지비율', '대학교 재학생수 비율 ']
#colors = ['#ff9999', '#ffc000', '#8fd9b6', '#d395d0']
wedgeprops={'width': .7, 'edgecolor': 'w', 'linewidth': 5}

plt.pie(ratio, labels=labels, startangle=260, counterclock=False, colors=colors, wedgeprops=wedgeprops)
plt.show()

# %%
import matplotlib.pyplot as plt

ratio = [21.74,13.27,9.55,0.00,0.77,0.00, 33.50,14.41,2.80, 2.65,  7.47, 0.00 ]
labels = ['M세대인구비율', 'Z세대인구비율', '아파트수 비율', '주상복합수 비율', '도시 생활형주택수 비율', '연립주택수 비율',
         '가구소득 600만원 이상', '1인당 평균 소비 금액', 'M세대사업체수비율', 'M세대종사자수비율', '사업체유지비율', '대학교 재학생수 비율 ']
#colors = ['#ff9999', '#ffc000', '#8fd9b6', '#d395d0']
wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5}


plt.pie(ratio,   counterclock=False, colors=colors, wedgeprops=wedgeprops)
plt.legend(loc = (2, 0.0))

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import matplotlib.pyplot as plt

ratio = [22.80,12.42,20.53,25.19,2.36,0.00, 11.70,8.01,5.51, 4.85, 7.46, 0 ]
labels = ['M세대인구비율', 'Z세대인구비율', '아파트수 비율', '주상복합수 비율', '도시 생활형주택수 비율', '연립주택수 비율',
         '가구소득 600만원 이상', '1인당 평균 소비 금액', 'M세대사업체수비율', 'M세대종사자수비율', '사업체유지비율', '대학교 재학생수 비율 ']
#colors = ['#ff9999', '#ffc000', '#8fd9b6', '#d395d0']
wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5}


plt.pie(ratio, labels=labels,  autopct='%.1f%%', counterclock=False, colors=colors, wedgeprops=wedgeprops)
plt.legend(loc = (2, 0.0))

plt.show()

# %%
import matplotlib.pyplot as plt

ratio = [25.29, 10.12, 10.15, 48.86, 88.19, 0.00, 20.50, 8.22, 5.89, 5.64, 5.18, 0]
labels = ['M세대인구비율', 'Z세대인구비율', '아파트수 비율', '주상복합수 비율', '도시 생활형주택수 비율', '연립주택수 비율',
         '가구소득 600만원 이상', '1인당 평균 소비 금액', 'M세대사업체수비율', 'M세대종사자수비율', '사업체유지비율', '대학교 재학생수 비율 ']
#colors = ['#ff9999', '#ffc000', '#8fd9b6', '#d395d0']
wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5}


plt.pie(ratio, labels=labels,  counterclock=False, colors=colors, wedgeprops=wedgeprops)
plt.legend(loc = (2, 0.0))

plt.show()

# %%
import matplotlib.pyplot as plt

ratio = [8.333333333333333, 8.333333333333333, 8.333333333333333, 8.333333333333333, 8.333333333333333, 8.333333333333333, 8.333333333333333, 8.333333333333333, 8.333333333333333, 8.333333333333333, 8.333333333333333, 8.333333333333333]
labels = ['M세대인구비율', 'Z세대인구비율', '아파트수 비율', '주상복합수 비율', '도시 생활형주택수 비율', '연립주택수 비율',
         '가구소득 600만원 이상', '1인당 평균 소비 금액', 'M세대사업체수비율', 'M세대종사자수비율', '사업체유지비율', '대학교 재학생수 비율 ']
explode = [0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05]

#colors = ['#ff9999', '#ffc000', '#8fd9b6', '#d395d0']

plt.pie(ratio, labels=labels,  startangle=260, counterclock=False, explode=explode, shadow=True, colors=colors)
plt.show()
